# %%
import pandas as pd

# %%
df = pd.read_csv("melbourne.csv")

# %%
df
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h        NaN      S
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df.isnull().sum()
# Out:
# Suburb               0
# Address              0
# Rooms                0
# Type                 0
# Price             5151
# Method               0
# SellerG              0
# Date                 0
# Distance             1
# Postcode             1
# Bedroom2          4481
# Bathroom          4484
# Car               4626
# Landsize          6137
# BuildingArea     13529
# YearBuilt        12007
# CouncilArea       7891
# Lattitude         4304
# Longtitude        4304
# Regionname           1
# Propertycount        1
# dtype: int64

# %%
df_cleaned=df.loc[:,(df.isnull().sum()/len(df)*100)<=30]
df_cleaned
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23543  Wyndham Vale    19 Dalrymple Bvd      4    h        NaN      S
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#              SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df_cleaned.isnull().sum()/len(df)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.875398
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.004247
# Postcode          0.004247
# Bedroom2         19.030025
# Bathroom         19.042766
# Car              19.645815
# Landsize         26.062768
# Lattitude        18.278337
# Longtitude       18.278337
# Regionname        0.004247
# Propertycount     0.004247
# dtype: float64

# %%
df_cleaned=df_cleaned[df_cleaned.isnull().sum(axis=1)<3]
df_cleaned
# Out:
#              Suburb           Address  Rooms Type      Price Method  \
# 1        Abbotsford      85 Turner St      2    h  1480000.0      S
# 2        Abbotsford   25 Bloomburg St      2    h  1035000.0      S
# 4        Abbotsford      5 Charles St      3    h  1465000.0     SP
# 5        Abbotsford  40 Federation La      3    h   850000.0     PI
# 6        Abbotsford       55a Park St      4    h  1600000.0     VB
# ...             ...               ...    ...  ...        ...    ...
# 19735  Williamstown       87 Pasco St      3    h  1285000.0      S
# 19736       Windsor   201/152 Peel St      2    u   560000.0     PI
# 19737       Wollert   60 Saltlake Bvd      3    h   525300.0      S
# 19738    Yarraville       2 Adeney St      2    h   750000.0     SP
# 19739    Yarraville   54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# 1             Biggin  03-12-2016       2.5    3067.0  ...       1.0  1.0
# ...

# %%
df_cleaned.isnull().sum()/len(df)*100
df_cleaned
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23541  Williamstown        96 Verdon St      4    h  2500000.0     PI
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df_cleaned
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 23541  Williamstown        96 Verdon St      4    h  2500000.0     PI
# 23542  Wyndham Vale     25 Clitheroe Dr      3    u        NaN     PN
# 23544     Yallambie        17 Amaroo Wy      4    h  1100000.0      S
# 23545    Yarraville          6 Agnes St      4    h  1285000.0     SP
# 23546    Yarraville       33 Freeman St      4    h  1050000.0     VB
#
#           SellerG        Date  Distance  Postcode  Bedroom2  Bathroom  Car  \
# ...

# %%
df_cleaned.isnull().sum()/len(df_cleaned)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.708801
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.015735
# Car               0.760516
# Landsize          8.690863
# Lattitude         0.136368
# Longtitude        0.136368
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df_cleaned = df.dropna(subset=['CouncilArea'])

# %%
df_cleaned
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 19735  Williamstown         87 Pasco St      3    h  1285000.0      S
# 19736       Windsor     201/152 Peel St      2    u   560000.0     PI
# 19737       Wollert     60 Saltlake Bvd      3    h   525300.0      S
# 19738    Yarraville         2 Adeney St      2    h   750000.0     SP
# 19739    Yarraville     54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df_cleaned.isnull().sum()/len(df_cleaned)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.863822
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.000000
# Car               0.000000
# Landsize          0.000000
# BuildingArea     46.461421
# YearBuilt        38.368677
# CouncilArea       0.000000
# Lattitude         0.166071
# Longtitude        0.166071
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df_cleaned = df.dropna(subset=['Lattitude'])
df_cleaned = df.dropna(subset=['Longtitude'])

# %%
df_cleaned.isnull().sum()/len(df_cleaned)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.716988
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          1.054929
# Bathroom          1.070519
# Car               1.808450
# Landsize          9.660656
# BuildingArea     47.986281
# YearBuilt        40.076911
# CouncilArea      18.775659
# Lattitude         0.000000
# Longtitude        0.000000
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df_cleaned = df_cleaned.dropna(subset=['Bedroom2','Bathroom','Car','CouncilArea'])
df_cleaned
# Out:
#              Suburb             Address  Rooms Type      Price Method  \
# 0        Abbotsford       68 Studley St      2    h        NaN     SS
# 1        Abbotsford        85 Turner St      2    h  1480000.0      S
# 2        Abbotsford     25 Bloomburg St      2    h  1035000.0      S
# 3        Abbotsford  18/659 Victoria St      3    u        NaN     VB
# 4        Abbotsford        5 Charles St      3    h  1465000.0     SP
# ...             ...                 ...    ...  ...        ...    ...
# 19735  Williamstown         87 Pasco St      3    h  1285000.0      S
# 19736       Windsor     201/152 Peel St      2    u   560000.0     PI
# 19737       Wollert     60 Saltlake Bvd      3    h   525300.0      S
# 19738    Yarraville         2 Adeney St      2    h   750000.0     SP
# 19739    Yarraville     54 Pentland Pde      6    h  2450000.0     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df_cleaned.isnull().sum()/len(df_cleaned)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price            21.874600
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.000000
# Car               0.000000
# Landsize          0.000000
# BuildingArea     46.429942
# YearBuilt        38.323736
# CouncilArea       0.000000
# Lattitude         0.000000
# Longtitude        0.000000
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df_cleaned=df_cleaned.dropna(subset=['YearBuilt'])
df_cleaned
# Out:
#              Suburb          Address  Rooms Type         Price Method  \
# 2        Abbotsford  25 Bloomburg St      2    h  1.035000e+06      S
# 4        Abbotsford     5 Charles St      3    h  1.465000e+06     SP
# 6        Abbotsford      55a Park St      4    h  1.600000e+06     VB
# 7        Abbotsford     16 Maugie St      4    h  1.053877e+06     SN
# 8        Abbotsford     53 Turner St      2    h  1.053877e+06      S
# ...             ...              ...    ...  ...           ...    ...
# 19732    Whittlesea    30 Sherwin St      3    h  6.010000e+05      S
# 19733  Williamstown      75 Cecil St      3    h  1.050000e+06     VB
# 19734  Williamstown    2/29 Dover Rd      1    u  3.850000e+05     SP
# 19736       Windsor  201/152 Peel St      2    u  5.600000e+05     PI
# 19739    Yarraville  54 Pentland Pde      6    h  2.450000e+06     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df_cleaned=df_cleaned.dropna(subset=['Price'])
df_cleaned
# Out:
#              Suburb          Address  Rooms Type         Price Method  \
# 2        Abbotsford  25 Bloomburg St      2    h  1.035000e+06      S
# 4        Abbotsford     5 Charles St      3    h  1.465000e+06     SP
# 6        Abbotsford      55a Park St      4    h  1.600000e+06     VB
# 7        Abbotsford     16 Maugie St      4    h  1.053877e+06     SN
# 8        Abbotsford     53 Turner St      2    h  1.053877e+06      S
# ...             ...              ...    ...  ...           ...    ...
# 19732    Whittlesea    30 Sherwin St      3    h  6.010000e+05      S
# 19733  Williamstown      75 Cecil St      3    h  1.050000e+06     VB
# 19734  Williamstown    2/29 Dover Rd      1    u  3.850000e+05     SP
# 19736       Windsor  201/152 Peel St      2    u  5.600000e+05     PI
# 19739    Yarraville  54 Pentland Pde      6    h  2.450000e+06     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df_cleaned.isnull().sum()/len(df_cleaned)*100
# Out:
# Suburb            0.000000
# Address           0.000000
# Rooms             0.000000
# Type              0.000000
# Price             0.000000
# Method            0.000000
# SellerG           0.000000
# Date              0.000000
# Distance          0.000000
# Postcode          0.000000
# Bedroom2          0.000000
# Bathroom          0.000000
# Car               0.000000
# Landsize          0.000000
# BuildingArea     16.338174
# YearBuilt         0.000000
# CouncilArea       0.000000
# Lattitude         0.000000
# Longtitude        0.000000
# Regionname        0.000000
# Propertycount     0.000000
# dtype: float64

# %%
df_cleaned=df_cleaned.dropna(subset=['BuildingArea'])
df_cleaned
# Out:
#              Suburb          Address  Rooms Type         Price Method  \
# 2        Abbotsford  25 Bloomburg St      2    h  1.035000e+06      S
# 4        Abbotsford     5 Charles St      3    h  1.465000e+06     SP
# 6        Abbotsford      55a Park St      4    h  1.600000e+06     VB
# 7        Abbotsford     16 Maugie St      4    h  1.053877e+06     SN
# 11       Abbotsford     124 Yarra St      3    h  1.876000e+06      S
# ...             ...              ...    ...  ...           ...    ...
# 19732    Whittlesea    30 Sherwin St      3    h  6.010000e+05      S
# 19733  Williamstown      75 Cecil St      3    h  1.050000e+06     VB
# 19734  Williamstown    2/29 Dover Rd      1    u  3.850000e+05     SP
# 19736       Windsor  201/152 Peel St      2    u  5.600000e+05     PI
# 19739    Yarraville  54 Pentland Pde      6    h  2.450000e+06     VB
#
#              SellerG        Date  Distance  Postcode  ...  Bathroom  Car  \
# ...

# %%
df_cleaned.isnull().sum()/len(df_cleaned)*100
# Out:
# Suburb           0.0
# Address          0.0
# Rooms            0.0
# Type             0.0
# Price            0.0
# Method           0.0
# SellerG          0.0
# Date             0.0
# Distance         0.0
# Postcode         0.0
# Bedroom2         0.0
# Bathroom         0.0
# Car              0.0
# Landsize         0.0
# BuildingArea     0.0
# YearBuilt        0.0
# CouncilArea      0.0
# Lattitude        0.0
# Longtitude       0.0
# Regionname       0.0
# Propertycount    0.0
# dtype: float64

# %%
5
